# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
# <br />
# Анастасия, доброго дня! рад приветствовать тебя в финале) <br />
# Вот и он подобрался, поздравляю. Остался последний рывок в этом марафоне)<br>
# <br />
# Меня зовут Николай. <br />И на этом этапе Вашего движения к новой профессии от меня будут комментарии по написанному коду. <br />Чтобы меньше "мусорить эфир" и чтобы максимально наглядно отделяться от основного кода, есть предложение условиться в некоторых обозначениях:<br /> <br />
# <u><b>ТАКОЙ ШРИФТ</b></u> - всегда начало комментария <br />
# <font color='green'>такой шрифт</font> - комментарии о том, что всё ОК <br/>
# <font color='purple'>такой шрифт</font> - комментарии о том, что всё ОК по результату,<br> однако что есть ещё что-то или в коде или есть способы сделать более короткий или быстрый код <br/>
# <font color='red'>такой шрифт</font> - комментарии о том, что есть критичный момент, влияющий на бизнес-результат проекта.<br/>
# </font><br /><br />
# <font color='green'>Как и всегда в спринтах - ставлю своей целью максимально помочь. Поэтому, все мои комментарии - это только способ передать свой опыт для помощи в твоих достижениях.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#О-задаче" data-toc-modified-id="О-задаче-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>О задаче</a></span><ul class="toc-item"><li><span><a href="#Описание-услуг" data-toc-modified-id="Описание-услуг-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание услуг</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#План-работы" data-toc-modified-id="План-работы-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>План работы</a></span><ul class="toc-item"><li><span><a href="#Оценка-и-анализ-данных" data-toc-modified-id="Оценка-и-анализ-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Оценка и анализ данных</a></span></li><li><span><a href="#Подготовка-данных-для-построеия--моделей" data-toc-modified-id="Подготовка-данных-для-построеия--моделей-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Подготовка данных для построеия  моделей</a></span></li><li><span><a href="#Моделирование" data-toc-modified-id="Моделирование-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Моделирование</a></span></li><li><span><a href="#Обоснование-и-выводы" data-toc-modified-id="Обоснование-и-выводы-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Обоснование и выводы</a></span></li><li><span><a href="#Описание-полей-данных:" data-toc-modified-id="Описание-полей-данных:-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Описание полей данных:</a></span></li></ul></li><li><span><a href="#Выполнение-работы" data-toc-modified-id="Выполнение-работы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Выполнение работы</a></span><ul class="toc-item"><li><span><a href="#Оценка-и-анализ-данных" data-toc-modified-id="Оценка-и-анализ-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Оценка и анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-информации-о-договоре" data-toc-modified-id="Анализ-информации-о-договоре-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Анализ информации о договоре</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li><li><span><a href="#Персональные-данные-клиента" data-toc-modified-id="Персональные-данные-клиента-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Персональные данные клиента</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li><li><span><a href="#Информация-об-интернет-услугах" data-toc-modified-id="Информация-об-интернет-услугах-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Информация об интернет-услугах</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li><li><span><a href="#Информация-об-услугах-телефонии" data-toc-modified-id="Информация-об-услугах-телефонии-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>Информация об услугах телефонии</a></span></li><li><span><a href="#Промежуточный-вывод" data-toc-modified-id="Промежуточный-вывод-3.1.8"><span class="toc-item-num">3.1.8&nbsp;&nbsp;</span>Промежуточный вывод</a></span></li><li><span><a href="#Объединение-таблиц-и-исправление-ошибок" data-toc-modified-id="Объединение-таблиц-и-исправление-ошибок-3.1.9"><span class="toc-item-num">3.1.9&nbsp;&nbsp;</span>Объединение таблиц и исправление ошибок</a></span><ul class="toc-item"><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-3.1.9.1"><span class="toc-item-num">3.1.9.1&nbsp;&nbsp;</span>Пропуски</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1.10"><span class="toc-item-num">3.1.10&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных-для-построеия-моделей" data-toc-modified-id="Подготовка-данных-для-построеия-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Подготовка данных для построеия моделей</a></span><ul class="toc-item"><li><span><a href="#Целевой-признак" data-toc-modified-id="Целевой-признак-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Целевой признак</a></span></li><li><span><a href="#Добавление-признака" data-toc-modified-id="Добавление-признака-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Добавление признака</a></span></li><li><span><a href="#Зависимость-признаков" data-toc-modified-id="Зависимость-признаков-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Зависимость признаков</a></span></li><li><span><a href="#Удаление-признаков" data-toc-modified-id="Удаление-признаков-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Удаление признаков</a></span></li><li><span><a href="#Кодировка-категориальных-признаков" data-toc-modified-id="Кодировка-категориальных-признаков-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Кодировка категориальных признаков</a></span></li><li><span><a href="#Разделение-выборок" data-toc-modified-id="Разделение-выборок-3.2.6"><span class="toc-item-num">3.2.6&nbsp;&nbsp;</span>Разделение выборок</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.2.7"><span class="toc-item-num">3.2.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Моделирование" data-toc-modified-id="Моделирование-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Моделирование</a></span><ul class="toc-item"><li><span><a href="#LogisticRegression" data-toc-modified-id="LogisticRegression-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>LogisticRegression</a></span><ul class="toc-item"><li><span><a href="#Баланс-классов" data-toc-modified-id="Баланс-классов-3.3.1.1"><span class="toc-item-num">3.3.1.1&nbsp;&nbsp;</span>Баланс классов</a></span></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3.1.2"><span class="toc-item-num">3.3.1.2&nbsp;&nbsp;</span>Уменьшение выборки</a></span></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.3.1.3"><span class="toc-item-num">3.3.1.3&nbsp;&nbsp;</span>Увеличение выборки</a></span></li></ul></li><li><span><a href="#RandomForestClassifier" data-toc-modified-id="RandomForestClassifier-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>RandomForestClassifier</a></span><ul class="toc-item"><li><span><a href="#Баланс-классов" data-toc-modified-id="Баланс-классов-3.3.2.1"><span class="toc-item-num">3.3.2.1&nbsp;&nbsp;</span>Баланс классов</a></span></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3.2.2"><span class="toc-item-num">3.3.2.2&nbsp;&nbsp;</span>Уменьшение выборки</a></span></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.3.2.3"><span class="toc-item-num">3.3.2.3&nbsp;&nbsp;</span>Увеличение выборки</a></span></li></ul></li><li><span><a href="#CatBoost" data-toc-modified-id="CatBoost-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>CatBoost</a></span><ul class="toc-item"><li><span><a href="#Баланс-классов" data-toc-modified-id="Баланс-классов-3.3.3.1"><span class="toc-item-num">3.3.3.1&nbsp;&nbsp;</span>Баланс классов</a></span></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3.3.2"><span class="toc-item-num">3.3.3.2&nbsp;&nbsp;</span>Уменьшение выборки</a></span></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.3.3.3"><span class="toc-item-num">3.3.3.3&nbsp;&nbsp;</span>Увеличение выборки</a></span></li></ul></li><li><span><a href="#Проверка-на-адекватность" data-toc-modified-id="Проверка-на-адекватность-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Проверка на адекватность</a></span></li></ul></li><li><span><a href="#Сравнение-моделей-и-выбор-лучшей" data-toc-modified-id="Сравнение-моделей-и-выбор-лучшей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Сравнение моделей и выбор лучшей</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Отчёт" data-toc-modified-id="Отчёт-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Отчёт</a></span></li></ul></div>

# %% [markdown]
# ## О задаче

# %% [markdown]
# Оператор связи хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# - Выделенная линия технической поддержки (*TechSupport*);
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
# ### Описание данных
#
# Данные состоят из файлов, полученных из разных источников.
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ## План работы
#
# ### Оценка и анализ данных
#
# Посмотреть содержимое полученных таблиц с данными. Проверить наличие пропусков, дубликатов, ошибок в типах даных и названиях, посмотреть распределение и наличие выбросов. При наличии ошибок и проблем, исправить их (заполнить\удалить пропуски, убрать дубликаты, заменить тип данных и т.д.). <br>
# Визуализировать данные, проверить зависимости признаков и (при необходимости) объединить таблицы.
#
# ### Подготовка данных для построеия  моделей
#
# 1. Кодирование категориальных признаков для корректной работы моделей.
# 2. Проведеие баланса данных разными способами (взвешиваие классов, уменьшение и увеличение выборки)
# 3. При необходимости исключение (добавление) признаков.
# 4. Определение целевого признака
# 5. Разбивание всех данных на обучающую и валидационную выборки
#
# ### Моделирование
#
# Выбор разных моделей для обучения и подбор параметров. Визуализация и выбор лучшей модели с наиболее высоким показателем качества.
#
# ### Обоснование и выводы
#
# Обосновать, почему были выбраны те или иные методы работы с данными и выбор конкретной модели, а также визуализировать конечный результат и подвести итог.
#
# ### Описание полей данных:
#
# - BeginDate – дата начала пользования услугами,
# - EndDate – дата окончания пользования услугами,
# - Type – тип оплаты: ежемесячный, годовой и тд,
# - PaperlessBilling – безналичный расчет,
# - PaymentMethod – способ оплаты,
# - MonthlyCharges – ежемесячные траты на услуги,
# - TotalCharges – всего потрачено денег на услуги
# - Dependents – наличие иждивенцев
# - Senior Citizen – наличие пенсионного статуса по возрасту
# - Partner – наличие супруга(и)
# - MultipleLines – наличие возможности ведения параллельных линий во время звонка

# %% [markdown]
# ## Выполнение работы

# %% [markdown]
# ### Оценка и анализ данных

# %%
import pandas as pd
import numpy as np
import seaborn as sb
from matplotlib import pyplot as plt
import phik
from phik.report import plot_correlation_matrix
from datetime import datetime, date, time
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer
from sklearn.ensemble import RandomForestClassifier
import optuna
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler 
from sklearn.dummy import DummyClassifier
#from sklearn.ensemble import RandomForestClassifier
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Анализ информации о договоре

# %% [markdown]
# **Проанализирую тдельно каждую таблицу с данными**

# %%
try:
    contract=pd.read_csv(r'........', sep=',')
    pd.set_option('display.max_columns', None) 
except:
    contract=pd.read_csv('......', sep=',')
    pd.set_option('display.max_columns', None)

# %%
def evaluation(data): #Функция для вывода общей информации о таблице: статистика, пропуски, дубликаты и т.д.
    information=(display('ИНФОРМАЦИЯ О ДАННЫХ',data.head(5)), display(data.info()), display('СТАТИСТИКА',data.describe()), display(data.describe(include=['object', 'bool'])), display('ЗАВИСИМОСТЬ ПРИЗНАКОВ',data.corr()), display('ПРОЦЕНТ ПРОПУЩЕННЫХ ЗНАЧЕНИЙ',data.isna().mean()*100), display('ДУБЛИКАТЫ',data.duplicated().sum()))
    return information

evaluation(contract)
# Out:
# 'ИНФОРМАЦИЯ О ДАННЫХ'
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
# ...

# %% [markdown]
# **Данные в столбце TotalCharges, содержащем числовые значеня, представлены в виде категориальных. Для дальнейшей работы, их необходимо перевести в floatб предварительно удалив лишние символы "**

# %%
contract['TotalCharges']=contract['TotalCharges'].str.extract('([0-9.]+)').astype(float)

# %%
contract.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7032 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 440.3+ KB

# %%
contract.hist(figsize = (10,7))
# Out:
# array([[<AxesSubplot:title={'center':'MonthlyCharges'}>,
#         <AxesSubplot:title={'center':'TotalCharges'}>]], dtype=object)

# %%
fig, axs = plt.subplots(1,2)


contract['MonthlyCharges'].plot(kind='box',ax=axs[0],figsize = (10,7))
contract['TotalCharges'].plot(kind='box',ax=axs[1])

fig.suptitle('Выбросы',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Выбросы')

# %% [markdown]
# #### Промежуточный вывод

# %% [markdown]
# В представленной аблице нет пропусков и дубликатов. В колонке с данными о том,  сколько всего потрачено денег на услуги тип данных был объект, поскольу (предположительно), числовые данные были ошибочно внесены как текст. Для изменения типа данных были удалены кавычки.<br>
# В колонке с датами данные категориальные. Но на данном этапе я не стаа менять тип данных, поскольку на оценку содержимого таблицы это не влияет. Тип данных изменю перед подготовкой данных к моделированию.<br>
# Больше всего клиентов в месяц оплачивают 20-30 (единицы измерения не указаны), а за весь период обслуживания - до 1000.

# %% [markdown]
# #### Персональные данные клиента

# %%
try:
    personal=pd.read_csv(r'........', sep=',')
    pd.set_option('display.max_columns', None) 
except:
    personal=pd.read_csv('......', sep=',')
    pd.set_option('display.max_columns', None)

# %%
evaluation(personal)
# Out:
# 'ИНФОРМАЦИЯ О ДАННЫХ'
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# None
# 'СТАТИСТИКА'
#        SeniorCitizen
# count    7043.000000
# mean        0.162147
# std         0.368612
# min         0.000000
# ...

# %%
personal.hist(figsize = (10,7))
# Out:
# array([[<AxesSubplot:title={'center':'SeniorCitizen'}>]], dtype=object)

# %% [markdown]
# #### Промежуточный вывод

# %% [markdown]
# В таблице, содержащей персональные данные клиентов, отсутствуют пропуски и дубликаты. Единственный числовой признак (бинарный) указывает на наличие пенсионного статуса по возрасту.

# %% [markdown]
# #### Информация об интернет-услугах

# %%
try:
    internet=pd.read_csv(r'.......', sep=',')
    pd.set_option('display.max_columns', None) 
except:
    internet=pd.read_csv('.......', sep=',')
    pd.set_option('display.max_columns', None)

# %%
evaluation(internet)
# Out:
# 'ИНФОРМАЦИЯ О ДАННЫХ'
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
# ...

# %% [markdown]
# #### Промежуточный вывод

# %% [markdown]
# Данные в таблице с информацией по интернет-услугам также нет пропусков и дубликатов. Кроме того, все признаки категориальные.

# %% [markdown]
# #### Информация об услугах телефонии

# %%
try:
    phone=pd.read_csv(r'.........', sep=',')
    pd.set_option('display.max_columns', None) 
except:
    phone=pd.read_csv('.......', sep=',')
    pd.set_option('display.max_columns', None)

# %%
evaluation(phone)
# Out:
# 'ИНФОРМАЦИЯ О ДАННЫХ'
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# None
# 'СТАТИСТИКА'
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390
#         customerID MultipleLines
# count         6361          6361
# unique        6361             2
# top     5575-GNVDE            No
# freq             1          3390
# 'ЗАВИСИМОСТЬ ПРИЗНАКОВ'
# Empty DataFrame
# Columns: []
# Index: []
# ...

# %% [markdown]
# #### Промежуточный вывод

# %% [markdown]
# Данные в таблице с информацией по услугам телефонии также нет пропусков и дубликатов и все признаки категориальные.

# %% [markdown]
# #### Объединение таблиц и исправление ошибок

# %% [markdown]
# **Учитывая связаность всех таблиц, предположу, что данные из четырёх таблиц будут иметь влияние на модель. Чтобы определить взаимосвязь призанков, оъеденю черыте таблицы в одну и буду в дальнейшем работать с ней.**

# %%
data=contract.merge(personal,how='left', on= 'customerID').merge(
    phone,how='left', on= 'customerID').merge(
    internet,how='left', on= 'customerID')

# %%
evaluation(data)
# Out:
# 'ИНФОРМАЦИЯ О ДАННЫХ'
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#    gender  SeniorCitizen Partner Dependents MultipleLines InternetService  \
# ...

# %% [markdown]
# ##### Пропуски

# %% [markdown]
# Так как не все клиенты оператора связи «Ниединогоразрыва.ком» пользуются интернет-услугами и телефонной связью одновременно, после объёдинения таблиц в данных посвились пропуски. В некоторый признаках их более 20 %. Удаление пустых значений существенно исказит информацию в целом. Предположу,что целесообразно применить "заглушку" и заполню пропуски 'unknown' и '0' для категорияльный и числовх признаков соотвественно.

# %%
def omissions(data):
    for col in data.columns:
        if data[col].dtype == "object":
            data[col] = data[col].fillna('unknown')
            data[col] = data[col].astype("object")
        if data[col].dtype == "float":
            data[col] = data[col].fillna(0)

# %%
omissions(data)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   float64
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  MultipleLines     7043 non-null   object
#  13  InternetService   7043 non-null   object
#  14  OnlineSecurity    7043 non-null   object
#  15  OnlineBackup      7043 non-null   object
# ...

# %% [markdown]
# #### Вывод

# %% [markdown]
# Данные всех таблиц были проверены на наличие ошибок. Пропусков и дубликатов обнаружено не было, однако в таблице, содержащей информаци о договорах, была ошибка в тах данных (чисовые данные были введены, как категориальные). Ошибка исправлена.<br>
# В связи с необходимостью работать и анализировать одновремено все данные, а также предоложительную важность признаков из разных датасетов, все таблицы были объеденины в одну.<br>
# После объединения образовались пропуски. Это связано с тем, что не все клиенты компании пользуются всеми её услугами. Соотвественно, данных по клиентах в некоторых признаках не может быть. Такие пропуски (в том числе и из-за их количества) удалять не стала, так как подобные действия исказят даных. Пустые значения заполнила "заглушкой".

# %% [markdown]
# ### Подготовка данных для построеия моделей

# %% [markdown]
# #### Целевой признак

# %% [markdown]
# *Прежде чем работать с данными, необходимо определить целевой признак. Ориентиром по условию задачи можно считать столбец `EndDate`, содержащий сведения о завершении обслуживания. Так как в изначальном виде данные колонки для модели не подходят, я создам бинарный признак, где 1-клиент, у которого есть дата ухда (т.е. это отток), а 0 - клиент, укоторого дата не стоит (он остаётся).*

# %%
def target_func (row):
    if row['EndDate']=='No':
        return 0
    else:
        return 1

# %%
data['target']=data.apply(target_func, axis=1)
data.head()
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check           29.85         29.85
# 1               No               Mailed check           56.95       1889.50
# 2              Yes               Mailed check           53.85        108.15
# 3               No  Bank transfer (automatic)           42.30       1840.75
# 4              Yes           Electronic check           70.70        151.65
#
#    gender  SeniorCitizen Partner Dependents MultipleLines InternetService  \
# ...

# %%
data['target'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Добавление признака

# %% [markdown]
# *Добавлю признак, содержащий информацию о длительности договора с клbентом (разница между окончанием и началом действия договора в днях). Для этого заполню окончание обслуживание, датой создания датафрейма (чтобы избежать утечки данных). Позже, после анализа зависимости признаков приму решение об удалении тех или иных столбцов.*

# %%
def new_func (row):
    if row['EndDate']:
        return '2020-02-01'
    

data['EndDate']=data.apply(new_func, axis=1)
data.head()
# Out:
#    customerID   BeginDate     EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  2020-01-01  2020-02-01  Month-to-month              Yes
# 1  5575-GNVDE  2017-04-01  2020-02-01        One year               No
# 2  3668-QPYBK  2019-10-01  2020-02-01  Month-to-month              Yes
# 3  7795-CFOCW  2016-05-01  2020-02-01        One year               No
# 4  9237-HQITU  2019-09-01  2020-02-01  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0           Electronic check           29.85         29.85  Female
# 1               Mailed check           56.95       1889.50    Male
# 2               Mailed check           53.85        108.15    Male
# 3  Bank transfer (automatic)           42.30       1840.75    Male
# 4           Electronic check           70.70        151.65  Female
#
#    SeniorCitizen Partner Dependents MultipleLines InternetService  \
# ...

# %%
 #Исправление типа данных
data['BeginDate']=pd.to_datetime(data['BeginDate'])
data['EndDate']=pd.to_datetime(data['EndDate'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   datetime64[ns]
#  2   EndDate           7043 non-null   datetime64[ns]
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   float64
#  8   gender            7043 non-null   object
#  9   SeniorCitizen     7043 non-null   int64
#  10  Partner           7043 non-null   object
#  11  Dependents        7043 non-null   object
#  12  MultipleLines     7043 non-null   object
#  13  InternetService   7043 non-null   object
#  14  OnlineSecurity    7043 non-null   object
#  15  OnlineBackup      7043 non-null   object
# ...

# %%
data['term']=data['EndDate']-data['BeginDate']

# %%
#Данные для работы необходимо перевести в числа
data['term']=(data['term'] / np.timedelta64(1, 'D')).astype(int)

# %% [markdown]
# **Фрмат даты модель не сможет обработать. Поэтому перевожу в число `BeginDate`**

# %%
data['BeginDate']=pd.to_datetime(data['BeginDate']).astype(np.int64)/10000000000000
data.head()
# Out:
#    customerID  BeginDate    EndDate            Type PaperlessBilling  \
# 0  7590-VHVEG  157783.68 2020-02-01  Month-to-month              Yes
# 1  5575-GNVDE  149100.48 2020-02-01        One year               No
# 2  3668-QPYBK  156988.80 2020-02-01  Month-to-month              Yes
# 3  7795-CFOCW  146206.08 2020-02-01        One year               No
# 4  9237-HQITU  156729.60 2020-02-01  Month-to-month              Yes
#
#                PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# 0           Electronic check           29.85         29.85  Female
# 1               Mailed check           56.95       1889.50    Male
# 2               Mailed check           53.85        108.15    Male
# 3  Bank transfer (automatic)           42.30       1840.75    Male
# 4           Electronic check           70.70        151.65  Female
#
#    SeniorCitizen Partner Dependents MultipleLines InternetService  \
# 0              0     Yes         No       unknown             DSL
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ РЕВЬЮЕРА</b></u></p>
#     <p>Я бы вообще факторы год и месяц не использовал.</p>
# </div>

# %% [markdown]
# #### Зависимость признаков

# %%
phik_target = data.phik_matrix()
# Out:
# interval columns not set, guessing: ['BeginDate', 'MonthlyCharges', 'TotalCharges', 'SeniorCitizen', 'target', 'term']

# %%
# нелинейная зависимость признаков к целевому
phik_target['target'].sort_values(ascending=False).round(2)
# Out:
# customerID          1.00
# target              1.00
# PaymentMethod       0.45
# BeginDate           0.42
# term                0.42
# MonthlyCharges      0.36
# PaperlessBilling    0.30
# TotalCharges        0.28
# Dependents          0.25
# Type                0.25
# SeniorCitizen       0.23
# Partner             0.23
# OnlineSecurity      0.21
# TechSupport         0.21
# InternetService     0.20
# OnlineBackup        0.18
# DeviceProtection    0.17
# StreamingMovies     0.14
# StreamingTV         0.14
# MultipleLines       0.02
# gender              0.00
# Name: target, dtype: float64

# %%
#Стастистическая значимость всех признаков
plot_correlation_matrix(phik_target.values, 
                        x_labels=phik_target.columns, 
                        y_labels=phik_target.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                     
                        fontsize_factor=1.5, 
                        figsize=(20, 18))
plt.tight_layout()
plt.title('Статистическая значимостть признаков', fontsize=30)
# Out:
# Text(0.5, 1.0, 'Статистическая значимостть признаков')

# %% [markdown]
# #### Удаление признаков

# %% [markdown]
# **Исходя из анализа зависимости признаков, целесообразно удалить, те, которые очень сильно коррелируют с целевым ( `customerID`, `EndDate`, а также те, которые никакого значения для модели нести не будут, согласно построенной выше диаграмме (`gender`, `MultipleLines`).**

# %%
data=data.drop(['customerID', 'EndDate', 'gender', 'MultipleLines'], axis=1)
data.head()
# Out:
#    BeginDate            Type PaperlessBilling              PaymentMethod  \
# 0  157783.68  Month-to-month              Yes           Electronic check
# 1  149100.48        One year               No               Mailed check
# 2  156988.80  Month-to-month              Yes               Mailed check
# 3  146206.08        One year               No  Bank transfer (automatic)
# 4  156729.60  Month-to-month              Yes           Electronic check
#
#    MonthlyCharges  TotalCharges  SeniorCitizen Partner Dependents  \
# 0           29.85         29.85              0     Yes         No
# 1           56.95       1889.50              0      No         No
# 2           53.85        108.15              0      No         No
# 3           42.30       1840.75              0      No         No
# 4           70.70        151.65              0      No         No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# ...

# %% [markdown]
# #### Кодировка категориальных признаков

# %% [markdown]
# *Так как не все модели могут работать с категориальными признаками, их надо кодировать в числовой ормат. Сделаю это с помощью ОНЕ.*

# %%
#Преобразование категориальных данных с помощию ОНЕ
data_ohe = pd.get_dummies(data,drop_first=True)
data_ohe.head()
# Out:
#    BeginDate  MonthlyCharges  TotalCharges  SeniorCitizen  target  term  \
# 0  157783.68           29.85         29.85              0       0    31
# 1  149100.48           56.95       1889.50              0       0  1036
# 2  156988.80           53.85        108.15              0       1   123
# 3  146206.08           42.30       1840.75              0       0  1371
# 4  156729.60           70.70        151.65              0       1   153
#
#    Type_One year  Type_Two year  PaperlessBilling_Yes  \
# 0              0              0                     1
# 1              1              0                     0
# 2              0              0                     1
# 3              1              0                     0
# 4              0              0                     1
#
#    PaymentMethod_Credit card (automatic)  PaymentMethod_Electronic check  \
# 0                                      0                               1
# ...

# %% [markdown]
# #### Разделение выборок

# %% [markdown]
# **Выборки для алгоритмов, не работающих с категориальными признаками**

# %%
features_train_ohe, features_test_ohe, target_train_ohe, target_test_ohe = train_test_split(
    data_ohe.drop('target', axis=1), data_ohe.target, test_size=0.15,
    random_state=12345, stratify=data_ohe['target'])

display('Размер признаков тренировочной выборки', features_train_ohe.shape)
display('Размер признаков тестовой выборки', features_test_ohe.shape)
display('Размер целевого признака', target_test_ohe.shape)
# Out:
# 'Размер признаков тренировочной выборки'
# (5986, 27)
# 'Размер признаков тестовой выборки'
# (1057, 27)
# 'Размер целевого признака'
# (1057,)

# %% [markdown]
# **Выборки для моделей, работающих с категориальными признаками**

# %%
features_train, features_test, target_train, target_test= train_test_split(
    data.drop('target', axis=1), data.target, test_size=0.15, random_state=12345, stratify=data['target'])

display('Размер признаков тренировочной выборки', features_train.shape)
display('Размер признаков тестовой выборки', features_test.shape)
display('Размер целевого признака',target_test.shape)
# Out:
# 'Размер признаков тренировочной выборки'
# (5986, 17)
# 'Размер признаков тестовой выборки'
# (1057, 17)
# 'Размер целевого признака'
# (1057,)

# %% [markdown]
# **Выборки для балансировки. Уменьшение и увеличение выборки.**

# %%
#Уменьшение выборки
def downsample(features, target, fraction):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=12345)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=12345)] + [target_ones])
    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=12345)
    
    return features_downsampled, target_downsampled

features_downsampled, target_downsampled = downsample(features_train, target_train, 0.1)
features_downsampled_ohe, target_downsampled_ohe = downsample(features_train_ohe, target_train_ohe, 0.1)

# %%
# Увеличение выборки
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

features_upsampled, target_upsampled = upsample(features_train, target_train, 10)
features_upsampled_ohe, target_upsampled_ohe = upsample(features_train_ohe, target_train_ohe, 10)

# %% [markdown]
# #### Вывод

# %% [markdown]
# В данных был выделен целевой признак, который будет необходим для прогнозирования оттока клиентов. Столбез содержит 1 и 0 для клиентов, у которых есть дата окончания договора и отсутсвует, соответственно.<br>
# Кроме того, я добавила признак, содержащий срок обслуживания клиентов И удалила прихнаки, которые предположительно малоинформативны для модели, а также слишком взаимосвязаны.<br>
# Для алгоритмов, не работающих с категориальными данными, закодировала информацию с помощью ОНЕ.<br>
# Данные разделены на выборки в соответсвии с типом алгоритмя и задачей (созданы выборки предположительно уменьшающие дисбаланс).

# %% [markdown]
# ### Моделирование

# %%
# Для добавления метрик в таблицу c результатами работы моделей
def metrics(result_train, result_test, accuracy_test, f1_test, model, data):
    data.loc[model, 'AUC-ROC_train'] = result_train
    data.loc[model, 'AUC-ROC_test'] = result_test
    data.loc[model, 'Accuracy_test'] = accuracy_test
    data.loc[model, 'F1_test'] = f1_test
    return data

# %%
# Таблица для сравнения результатов работы моделей
compare_models = pd.DataFrame(columns=['AUC-ROC_train', 'AUC-ROC_test', 'Accuracy_test','F1_test'])

# %% [markdown]
# #### LogisticRegression

# %% [markdown]
# **Во все алгоритмы добавлю параметр `class_weight` со значением `balanced`**

# %% [markdown]
# ##### Баланс классов

# %%
model_log = LogisticRegression(solver='liblinear',class_weight='balanced',random_state=12345)

scores_log = cross_val_score(model_log, features_train_ohe, target_train_ohe, cv=5, scoring='roc_auc')

model_log.fit(features_train_ohe, target_train_ohe)


result_log_train = roc_auc_score(target_train_ohe, model_log.predict_proba(features_train_ohe)[:, 1])
result_log_test = scores_log.mean()

accuracy=accuracy_score(target_test_ohe, model_log.predict(features_test_ohe)) 

f1=f1_score(target_test_ohe, model_log.predict(features_test_ohe))


'AUC-ROC на тренировочной выборке:', result_log_train, 'AUC-ROC на тестовой выборке:',  result_log_test, 'Accuracy',accuracy, 'F1',f1
# Out:
# ('AUC-ROC на тренировочной выборке:',
#  0.8385219741190323,
#  'AUC-ROC на тестовой выборке:',
#  0.8345668354678828,
#  'Accuracy',
#  0.7464522232734153,
#  'F1',
#  0.6308539944903582)

# %%
#Постоение ROC-кривой
probabilities_log = model_log.predict_proba(features_test_ohe)
probabilities_one_log = probabilities_log[:, 1]

fpr, tpr, thresholds = roc_curve(target_test_ohe, probabilities_one_log)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая логистической регрессии')
plt.show()

# %%
metrics(result_log_train, result_log_test, accuracy, f1, 'LogisticRegression', compare_models)
# Out:
#                    AUC-ROC_train AUC-ROC_test Accuracy_test   F1_test
# LogisticRegression      0.838522     0.834567      0.746452  0.630854

# %% [markdown]
# ##### Уменьшение выборки

# %%
model_log_down= LogisticRegression(solver='liblinear',class_weight='balanced',random_state=12345)

scores_log_down = cross_val_score(model_log_down, features_downsampled_ohe, target_downsampled_ohe, cv=5, scoring='roc_auc')

model_log_down.fit(features_downsampled_ohe, target_downsampled_ohe)

result_log_down_train = roc_auc_score(target_downsampled_ohe, model_log_down.predict_proba(features_downsampled_ohe)[:, 1])
result_log_down_test = scores_log_down.mean()

accuracy_down=accuracy_score(target_test_ohe, model_log.predict(features_test_ohe)) 

f1_down=f1_score(target_test_ohe, model_log.predict(features_test_ohe))


'AUC-ROC на тренировочной выборке:', result_log_down_train, 'AUC-ROC на тестовой выборке:',  result_log_down_test, 'Accuracy',accuracy_down, 'F1',f1_down
# Out:
# ('AUC-ROC на тренировочной выборке:',
#  0.851830768350592,
#  'AUC-ROC на тестовой выборке:',
#  0.8356065115171715,
#  'Accuracy',
#  0.7464522232734153,
#  'F1',
#  0.6308539944903582)

# %%
#Постоение ROC-кривой
probabilities_log_down = model_log_down.predict_proba(features_test_ohe)
probabilities_one_log_down = probabilities_log_down[:, 1]

fpr, tpr, thresholds = roc_curve(target_test_ohe, probabilities_one_log_down)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая логистической регрессии c уменьшением выборки')
plt.show()

# %%
metrics(result_log_down_train, result_log_down_test,accuracy_down, f1_down, 'LogisticRegression+downsampled', compare_models)
# Out:
#                                AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                  0.838522     0.834567      0.746452
# LogisticRegression+downsampled      0.851831     0.835607      0.746452
#
#                                  F1_test
# LogisticRegression              0.630854
# LogisticRegression+downsampled  0.630854

# %% [markdown]
# ##### Увеличение выборки

# %%
model_log_up= LogisticRegression(solver='liblinear',class_weight='balanced',random_state=12345)

scores_log_up = cross_val_score(model_log_up, features_upsampled_ohe, target_upsampled_ohe, cv=5, scoring='roc_auc')

model_log_up.fit(features_upsampled_ohe, target_upsampled_ohe)

result_log_up_train = roc_auc_score(target_upsampled_ohe, model_log_up.predict_proba(features_upsampled_ohe)[:, 1])
result_log_up_test = scores_log_up.mean()

accuracy_log_up=accuracy_score(target_test_ohe, model_log_up.predict(features_test_ohe)) 

f1_log_up=f1_score(target_test_ohe, model_log_up.predict(features_test_ohe))



'AUC-ROC на тренировочной выборке:', result_log_up_train, 'AUC-ROC на тестовой выборке:',  result_log_up_test, 'Accuracy',accuracy_log_up, 'F1',f1_log_up
# Out:
# ('AUC-ROC на тренировочной выборке:',
#  0.8400321003808162,
#  'AUC-ROC на тестовой выборке:',
#  0.8382831444702601,
#  'Accuracy',
#  0.7436140018921475,
#  'F1',
#  0.624133148404993)

# %%
#Постоение ROC-кривой
probabilities_log_up = model_log_up.predict_proba(features_test_ohe)
probabilities_one_log_up = probabilities_log_up[:, 1]

fpr, tpr, thresholds = roc_curve(target_test_ohe, probabilities_one_log_up)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая логистической регрессии c увеличением выборки')
plt.show()

# %%
metrics(result_log_up_train, result_log_up_test, accuracy_log_up, f1_log_up, 'LogisticRegression+upsampled', compare_models)
# Out:
#                                AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                  0.838522     0.834567      0.746452
# LogisticRegression+downsampled      0.851831     0.835607      0.746452
# LogisticRegression+upsampled        0.840032     0.838283      0.743614
#
#                                  F1_test
# LogisticRegression              0.630854
# LogisticRegression+downsampled  0.630854
# LogisticRegression+upsampled    0.624133

# %% [markdown]
# #### RandomForestClassifier

# %% [markdown]
# ##### Баланс классов

# %%
forest=RandomForestClassifier(
        random_state=12345,
        class_weight='balanced')

forest_params = {
    'max_depth': range(3, 10, 2),
    'n_estimators':range(100,400,50)
}

model= RandomizedSearchCV(forest,
        forest_params,
        scoring='roc_auc',
        cv=5)

model.fit(features_train_ohe, target_train_ohe)
params=model.best_params_

'Лучшие параметры',params
# Out:
# ('Лучшие параметры', {'n_estimators': 300, 'max_depth': 9})

# %%
model_forest = RandomForestClassifier(**params, random_state=12345,
        class_weight='balanced')
model_forest.fit(features_train_ohe, target_train_ohe)

result_forest_train=roc_auc_score(target_train_ohe, model_forest.predict_proba(features_train_ohe)[:, 1])
result_forest_test=model.best_score_

accuracy_for=accuracy_score(target_test_ohe, model_forest.predict(features_test_ohe)) 

f1_for=f1_score(target_test_ohe, model_forest.predict(features_test_ohe))


'AUC-ROC на тренировочной выборке:', result_forest_train, 'AUC-ROC на тестовой выборке:',  result_forest_test, 'Accuracy',accuracy_for, 'F1',f1_for
# Out:
# ('AUC-ROC на тренировочной выборке:',
#  0.9390038376471858,
#  'AUC-ROC на тестовой выборке:',
#  0.8815597837870041,
#  'Accuracy',
#  0.7909176915799432,
#  'F1',
#  0.6636225266362253)

# %%
#Постоение ROC-кривой
probabilities_forest = model_forest.predict_proba(features_test_ohe)
probabilities_one_forest = probabilities_forest[:,1]

fpr, tpr, thresholds = roc_curve(target_test_ohe, probabilities_one_forest)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая Случайного леса')
plt.show()

# %%
# Оценка значимости признаков для модели
importances_forest=pd.Series(model_forest.feature_importances_,
    features_train_ohe.columns)


fig, ax = plt.subplots(figsize=(16,10))
importances_forest.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
metrics(result_forest_train, result_forest_test, accuracy_for, f1_for, 'RandomForestClassifier', compare_models)
# Out:
#                                AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                  0.838522     0.834567      0.746452
# LogisticRegression+downsampled      0.851831     0.835607      0.746452
# LogisticRegression+upsampled        0.840032     0.838283      0.743614
# RandomForestClassifier              0.939004      0.88156      0.790918
#
#                                  F1_test
# LogisticRegression              0.630854
# LogisticRegression+downsampled  0.630854
# LogisticRegression+upsampled    0.624133
# RandomForestClassifier          0.663623

# %% [markdown]
# ##### Уменьшение выборки

# %%
model_down= RandomizedSearchCV(forest,
        forest_params,
        scoring='roc_auc',
        cv=5)

model_down.fit(features_downsampled_ohe, target_downsampled_ohe)
params_down=model_down.best_params_

'Лучшие параметры',params_down
# Out:
# ('Лучшие параметры', {'n_estimators': 350, 'max_depth': 9})

# %%
model_forest_down = RandomForestClassifier(**params_down, random_state=12345,
        class_weight='balanced')

model_forest_down.fit(features_downsampled_ohe, target_downsampled_ohe)


result_forest_down_train=roc_auc_score(target_downsampled_ohe, model_forest_down.predict_proba(features_downsampled_ohe)[:, 1])
result_forest_down_test=model_down.best_score_

accuracy_for_dow=accuracy_score(target_test_ohe, model_forest_down.predict(features_test_ohe)) 

f1_for_dow=f1_score(target_test_ohe, model_forest_down.predict(features_test_ohe))


'AUC-ROC на тренировочной выборке:', result_forest_down_train, 'AUC-ROC на тестовой выборке:',  result_forest_down_test, 'Accuracy',accuracy_for_dow, 'F1',f1_for_dow
# Out:
# ('AUC-ROC на тренировочной выборке:',
#  0.9867326506093025,
#  'AUC-ROC на тестовой выборке:',
#  0.8861484390359159,
#  'Accuracy',
#  0.6650898770104068,
#  'F1',
#  0.5921658986175116)

# %%
#Постоение ROC-кривой
probabilities_forest_down = model_down.predict_proba(features_test_ohe)
probabilities_one_forest_down = probabilities_forest_down[:,1]

fpr, tpr, thresholds = roc_curve(target_test_ohe, probabilities_one_forest_down)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая Случайного леса с уменьшением выборки')
plt.show()

# %%
# Оценка значимости признаков для модели
importances_forest_down = pd.Series(model_forest_down.feature_importances_,
                         features_downsampled_ohe.columns)

fig, ax = plt.subplots(figsize=(16,10))
importances_forest_down.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
metrics(result_forest_down_train, result_forest_down_test, accuracy_for_dow, f1_for_dow, 'RandomForestClassifier+downsampled', compare_models)
# Out:
#                                    AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                      0.838522     0.834567      0.746452
# LogisticRegression+downsampled          0.851831     0.835607      0.746452
# LogisticRegression+upsampled            0.840032     0.838283      0.743614
# RandomForestClassifier                  0.939004      0.88156      0.790918
# RandomForestClassifier+downsampled      0.986733     0.886148       0.66509
#
#                                      F1_test
# LogisticRegression                  0.630854
# LogisticRegression+downsampled      0.630854
# LogisticRegression+upsampled        0.624133
# RandomForestClassifier              0.663623
# RandomForestClassifier+downsampled  0.592166

# %% [markdown]
# ##### Увеличение выборки

# %%
model_up = RandomizedSearchCV(forest,
        forest_params,
        scoring='roc_auc',
        cv=5)

model_up.fit(features_downsampled_ohe, target_downsampled_ohe)
params_up=model_up.best_params_

'Лучшие параметры',params_up
# Out:
# ('Лучшие параметры', {'n_estimators': 300, 'max_depth': 9})

# %%
model_forest_up = RandomForestClassifier(**params_down, random_state=12345,
        class_weight='balanced')

model_forest_up.fit(features_upsampled_ohe, target_upsampled_ohe)

result_forest_up_train=roc_auc_score(target_upsampled_ohe, model_forest_up.predict_proba(features_upsampled_ohe)[:, 1])
result_forest_up_test=model_up.best_score_


accuracy_for_up=accuracy_score(target_test_ohe, model_forest_up.predict(features_test_ohe)) 

f1_for_up=f1_score(target_test_ohe, model_forest_up.predict(features_test_ohe))

'AUC-ROC на тренировочной выборке:', result_forest_up_train, 'AUC-ROC на тестовой выборке:',  result_forest_up_test, 'Accuracy',accuracy_for_up, 'F1',f1_for_up
# Out:
# ('AUC-ROC на тренировочной выборке:',
#  0.9444278974465256,
#  'AUC-ROC на тестовой выборке:',
#  0.8860841165659332,
#  'Accuracy',
#  0.783349101229896,
#  'F1',
#  0.6666666666666667)

# %%
#Постоение ROC-кривой
probabilities_forest_up = model_forest_up.predict_proba(features_test_ohe)
probabilities_one_forest_up = probabilities_forest_up[:,1]

fpr, tpr, thresholds = roc_curve(target_test_ohe, probabilities_one_forest_up)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая Случайного леса с увеличением выборки')
plt.show()

# %%
# Оценка значимости признаков для модели
importances_forest_up = pd.Series(model_forest_up.feature_importances_,
                         features_upsampled_ohe.columns)

fig, ax = plt.subplots(figsize=(16,10))
importances_forest_up.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
metrics(result_forest_up_train, result_forest_up_test,accuracy_for_up,f1_for_up, 'RandomForestClassifier+upsampled', compare_models)
# Out:
#                                    AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                      0.838522     0.834567      0.746452
# LogisticRegression+downsampled          0.851831     0.835607      0.746452
# LogisticRegression+upsampled            0.840032     0.838283      0.743614
# RandomForestClassifier                  0.939004      0.88156      0.790918
# RandomForestClassifier+downsampled      0.986733     0.886148       0.66509
# RandomForestClassifier+upsampled        0.944428     0.886084      0.783349
#
#                                      F1_test
# LogisticRegression                  0.630854
# LogisticRegression+downsampled      0.630854
# LogisticRegression+upsampled        0.624133
# RandomForestClassifier              0.663623
# RandomForestClassifier+downsampled  0.592166
# RandomForestClassifier+upsampled    0.666667

# %% [markdown]
# #### CatBoost

# %% [markdown]
# ##### Баланс классов

# %%
cat_features = data.dtypes[data.dtypes=="object"].index.values

model_cat = CatBoostClassifier(cat_features=cat_features,
                          max_depth=10,     
                          random_seed=12345,
                          verbose=100,
                          od_type = "Iter",
                          od_wait = 20)

model_cat.fit(features_train,target_train)



result_cat_train=roc_auc_score(target_train, model_cat.predict_proba(features_train)[:, 1])
result_cat_test=roc_auc_score(target_test, model_cat.predict_proba(features_test)[:, 1])

accuracy_cat=accuracy_score(target_test, model_cat.predict(features_test)) 

f1_cat=f1_score(target_test, model_cat.predict(features_test))

'AUC-ROC на тренировочной выборке:', result_cat_train, 'AUC-ROC на тестовой выборке:',  result_cat_test,'Accuracy',accuracy_cat, 'F1',f1_cat
# Out:
# Learning rate set to 0.022119
# 0:	learn: 0.6773151	total: 422ms	remaining: 7m 1s
# 100:	learn: 0.3354507	total: 19.1s	remaining: 2m 50s
# 200:	learn: 0.2922065	total: 36.9s	remaining: 2m 26s
# 300:	learn: 0.2665626	total: 54.2s	remaining: 2m 5s
# 400:	learn: 0.2359087	total: 1m 14s	remaining: 1m 52s
# 500:	learn: 0.2023360	total: 1m 36s	remaining: 1m 35s
# 600:	learn: 0.1747609	total: 1m 55s	remaining: 1m 17s
# 700:	learn: 0.1539580	total: 2m 16s	remaining: 58.1s
# 800:	learn: 0.1371707	total: 2m 36s	remaining: 38.8s
# 900:	learn: 0.1219238	total: 2m 56s	remaining: 19.4s
# 999:	learn: 0.1096948	total: 3m 17s	remaining: 0us
# ('AUC-ROC на тренировочной выборке:',
#  0.9937876001902435,
#  'AUC-ROC на тестовой выборке:',
#  0.918284611141754,
#  'Accuracy',
#  0.8789025543992431,
#  'F1',
#  0.7480314960629922)

# %%
#Постоение ROC-кривой
probabilities_cat = model_cat.predict_proba(features_test)
probabilities_one_cat = probabilities_cat[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_cat)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая модели CatBoost')
plt.show()

# %%
# Оценка значимости признаков для модели
importances_cat = pd.Series(model_cat.feature_importances_,
                         features_train.columns)

fig, ax = plt.subplots(figsize=(16,10))
importances_cat.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
metrics(result_cat_train, result_cat_test, accuracy_cat, f1_cat, 'CatBoost', compare_models)
# Out:
#                                    AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                      0.838522     0.834567      0.746452
# LogisticRegression+downsampled          0.851831     0.835607      0.746452
# LogisticRegression+upsampled            0.840032     0.838283      0.743614
# RandomForestClassifier                  0.939004      0.88156      0.790918
# RandomForestClassifier+downsampled      0.986733     0.886148       0.66509
# RandomForestClassifier+upsampled        0.944428     0.886084      0.783349
# CatBoost                                0.993788     0.918285      0.878903
#
#                                      F1_test
# LogisticRegression                  0.630854
# LogisticRegression+downsampled      0.630854
# LogisticRegression+upsampled        0.624133
# RandomForestClassifier              0.663623
# RandomForestClassifier+downsampled  0.592166
# RandomForestClassifier+upsampled    0.666667
# ...

# %% [markdown]
# ##### Уменьшение выборки

# %%
model_cat = CatBoostClassifier(cat_features=cat_features,max_depth=10,
                          random_seed=12345,
                          verbose=100,
                          od_type = "Iter",
                          od_wait = 20,
                          learning_rate=0.1)

cat_down=model_cat.fit(features_downsampled, target_downsampled)

result_cat_down_train=roc_auc_score(target_downsampled, cat_down.predict_proba(features_downsampled)[:, 1])
result_cat_down_test=roc_auc_score(target_test, cat_down.predict_proba(features_test)[:, 1])

accuracy_cat_down=accuracy_score(target_test, cat_down.predict(features_test)) 

f1_cat_down=f1_score(target_test, cat_down.predict(features_test))

'AUC-ROC на тренировочной выборке:', result_cat_down_train, 'AUC-ROC на тестовой выборке:',  result_cat_down_test,'Accuracy',accuracy_cat_down, 'F1',f1_cat_down
# Out:
# 0:	learn: 0.6165206	total: 275ms	remaining: 4m 35s
# 100:	learn: 0.1531029	total: 15.4s	remaining: 2m 17s
# 200:	learn: 0.0697930	total: 33.8s	remaining: 2m 14s
# 300:	learn: 0.0390608	total: 51.9s	remaining: 2m
# 400:	learn: 0.0265628	total: 1m 10s	remaining: 1m 44s
# 500:	learn: 0.0194911	total: 1m 29s	remaining: 1m 28s
# 600:	learn: 0.0152206	total: 1m 48s	remaining: 1m 12s
# 700:	learn: 0.0131236	total: 2m 7s	remaining: 54.3s
# 800:	learn: 0.0115736	total: 2m 26s	remaining: 36.3s
# 900:	learn: 0.0106184	total: 2m 45s	remaining: 18.2s
# 999:	learn: 0.0095938	total: 3m 3s	remaining: 0us
# ('AUC-ROC на тренировочной выборке:',
#  0.9976629097774472,
#  'AUC-ROC на тестовой выборке:',
#  0.8863577863577863,
#  'Accuracy',
#  0.6376537369914853,
#  'F1',
#  0.579582875960483)

# %%
#Постоение ROC-кривой
probabilities_cat_down = cat_down.predict_proba(features_test)
probabilities_one_cat_down = probabilities_cat_down[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_cat_down)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая модели CatBoost с уменьшением выборки')
plt.show()

# %%
# Оценка значимости признаков для модели
importances_cat_down = pd.Series(cat_down.feature_importances_,
                         features_downsampled.columns)

fig, ax = plt.subplots(figsize=(16,10))
importances_cat_down.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
metrics(result_cat_down_train, result_cat_down_test, accuracy_cat_down, f1_cat_down, 'CatBoost+downsampled', compare_models)
# Out:
#                                    AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                      0.838522     0.834567      0.746452
# LogisticRegression+downsampled          0.851831     0.835607      0.746452
# LogisticRegression+upsampled            0.840032     0.838283      0.743614
# RandomForestClassifier                  0.939004      0.88156      0.790918
# RandomForestClassifier+downsampled      0.986733     0.886148       0.66509
# RandomForestClassifier+upsampled        0.944428     0.886084      0.783349
# CatBoost                                0.993788     0.918285      0.878903
# CatBoost+downsampled                    0.997663     0.886358      0.637654
#
#                                      F1_test
# LogisticRegression                  0.630854
# LogisticRegression+downsampled      0.630854
# LogisticRegression+upsampled        0.624133
# RandomForestClassifier              0.663623
# RandomForestClassifier+downsampled  0.592166
# ...

# %% [markdown]
# ##### Увеличение выборки

# %%
model_cat = CatBoostClassifier(cat_features=cat_features,
                          max_depth=10,
                          random_seed=12345,
                          verbose=100,
                          od_type = "Iter",
                          od_wait = 20,
                          learning_rate=0.1
                          )
cat_up=model_cat.fit(features_upsampled, target_upsampled)

result_cat_up_train=roc_auc_score(target_upsampled, cat_up.predict_proba(features_upsampled)[:, 1])
result_cat_up_test=roc_auc_score(target_test, cat_up.predict_proba(features_test)[:, 1])

accuracy_cat_up=accuracy_score(target_test, cat_up.predict(features_test)) 

f1_cat_up=f1_score(target_test, cat_up.predict(features_test))

'AUC-ROC на тренировочной выборке:', result_cat_up_train, 'AUC-ROC на тестовой выборке:',  result_cat_up_test, 'Accuracy',accuracy_cat_up, 'F1',f1_cat_up
# Out:
# 0:	learn: 0.6151690	total: 368ms	remaining: 6m 7s
# 100:	learn: 0.1340223	total: 39.6s	remaining: 5m 52s
# 200:	learn: 0.0653997	total: 1m 17s	remaining: 5m 9s
# 300:	learn: 0.0401070	total: 1m 56s	remaining: 4m 29s
# 400:	learn: 0.0274430	total: 2m 35s	remaining: 3m 52s
# 500:	learn: 0.0199419	total: 3m 13s	remaining: 3m 13s
# 600:	learn: 0.0152682	total: 3m 53s	remaining: 2m 34s
# 700:	learn: 0.0120954	total: 4m 31s	remaining: 1m 56s
# 800:	learn: 0.0101601	total: 5m 11s	remaining: 1m 17s
# 900:	learn: 0.0091639	total: 5m 52s	remaining: 38.8s
# 999:	learn: 0.0086533	total: 6m 35s	remaining: 0us
# ('AUC-ROC на тренировочной выборке:',
#  0.9999999999999999,
#  'AUC-ROC на тестовой выборке:',
#  0.9173883066740209,
#  'Accuracy',
#  0.8647114474929044,
#  'F1',
#  0.7588532883642495)

# %%
#Постоение ROC-кривой
probabilities_cat_up = cat_up.predict_proba(features_test)
probabilities_one_cat_up = probabilities_cat_up[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_cat_up)

plt.figure(figsize=(5,5))
plt.plot(fpr, tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('Ложно положительные')
plt.ylabel('Истинно положительные')
plt.title('ROC-кривая модели CatBoost с увеличением выборки')
plt.show()

# %%
# Оценка значимости признаков для модели
importances_cat_up = pd.Series(cat_up.feature_importances_,
                         features_upsampled.columns)

fig, ax = plt.subplots(figsize=(16,10))
importances_cat_up.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
metrics(result_cat_up_train, result_cat_up_test, accuracy_cat_up, f1_cat_up, 'CatBoost+upsampled', compare_models)
# Out:
#                                    AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                      0.838522     0.834567      0.746452
# LogisticRegression+downsampled          0.851831     0.835607      0.746452
# LogisticRegression+upsampled            0.840032     0.838283      0.743614
# RandomForestClassifier                  0.939004      0.88156      0.790918
# RandomForestClassifier+downsampled      0.986733     0.886148       0.66509
# RandomForestClassifier+upsampled        0.944428     0.886084      0.783349
# CatBoost                                0.993788     0.918285      0.878903
# CatBoost+downsampled                    0.997663     0.886358      0.637654
# CatBoost+upsampled                           1.0     0.917388      0.864711
#
#                                      F1_test
# LogisticRegression                  0.630854
# LogisticRegression+downsampled      0.630854
# LogisticRegression+upsampled        0.624133
# ...

# %% [markdown]
# #### Проверка на адекватность

# %%
dummy = DummyClassifier(strategy='constant', random_state=None, constant=1)

dummy.fit(features_train_ohe, target_train_ohe)


result_dummy_train=roc_auc_score(target_train_ohe, dummy.predict_proba(features_train_ohe)[:, 1])
result_dummy_test=roc_auc_score(target_test_ohe, dummy.predict_proba(features_test_ohe)[:, 1])

accuracy_dummy=accuracy_score(target_test_ohe, dummy.predict(features_test_ohe)) 

f1_dummy=f1_score(target_test_ohe, dummy.predict(features_test_ohe))



'AUC-ROC базовой модели для тренировочной выборки ', result_dummy_train, ',AUC-ROC базовой модели для тестовой выборки', result_dummy_test, 'Accuracy',accuracy_dummy, 'F1',f1_dummy
# Out:
# ('AUC-ROC базовой модели для тренировочной выборки ',
#  0.5,
#  ',AUC-ROC базовой модели для тестовой выборки',
#  0.5,
#  'Accuracy',
#  0.26490066225165565,
#  'F1',
#  0.41884816753926707)

# %%
metrics(result_dummy_train, result_dummy_test, accuracy_dummy, f1_dummy,'Базовая модель', compare_models)
# Out:
#                                    AUC-ROC_train AUC-ROC_test Accuracy_test  \
# LogisticRegression                      0.838522     0.834567      0.746452
# LogisticRegression+downsampled          0.851831     0.835607      0.746452
# LogisticRegression+upsampled            0.840032     0.838283      0.743614
# RandomForestClassifier                  0.939004      0.88156      0.790918
# RandomForestClassifier+downsampled      0.986733     0.886148       0.66509
# RandomForestClassifier+upsampled        0.944428     0.886084      0.783349
# CatBoost                                0.993788     0.918285      0.878903
# CatBoost+downsampled                    0.997663     0.886358      0.637654
# CatBoost+upsampled                           1.0     0.917388      0.864711
# Базовая модель                               0.5          0.5      0.264901
#
#                                      F1_test
# LogisticRegression                  0.630854
# ...

# %% [markdown]
# ### Сравнение моделей и выбор лучшей

# %%
compare_models=compare_models.sort_values(by='AUC-ROC_test', ascending=False).reset_index()
compare_models
# Out:
#                                 index AUC-ROC_train AUC-ROC_test  \
# 0                            CatBoost      0.993788     0.918285
# 1                  CatBoost+upsampled           1.0     0.917388
# 2                CatBoost+downsampled      0.997663     0.886358
# 3  RandomForestClassifier+downsampled      0.986733     0.886148
# 4    RandomForestClassifier+upsampled      0.944428     0.886084
# 5              RandomForestClassifier      0.939004      0.88156
# 6        LogisticRegression+upsampled      0.840032     0.838283
# 7      LogisticRegression+downsampled      0.851831     0.835607
# 8                  LogisticRegression      0.838522     0.834567
# 9                      Базовая модель           0.5          0.5
#
#   Accuracy_test   F1_test
# 0      0.878903  0.748031
# 1      0.864711  0.758853
# 2      0.637654  0.579583
# 3       0.66509  0.592166
# 4      0.783349  0.666667
# 5      0.790918  0.663623
# 6      0.743614  0.624133
# 7      0.746452  0.630854
# ...

# %%
fig, axs = plt.subplots(1,4)

compare_models.plot(kind='bar', x='index', y= 'AUC-ROC_train',color='green', label='AUC_ROC обучающая выборка',ax=axs[0], figsize=(15,7))
compare_models.plot(kind='bar', x='index', y= 'AUC-ROC_test',color='blue', label='AUC_ROC тестовя выборка', ax=axs[1])
compare_models.plot(kind='bar', x='index', y= 'Accuracy_test',color='pink', label='Accuracy тестовя выборка',ax=axs[2])
compare_models.plot(kind='bar', x='index', y= 'F1_test',color='brown', label='F1_test тестовя выборка', ax=axs[3])


fig.suptitle('Сравнение качества  работы моделей',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Сравнение качества  работы моделей')

# %% [markdown]
# #### Вывод

# %% [markdown]
# На подготовленных данных было очучено три модели: `LogisticRegression`, `RandomForestClassifier`, `CatBoost`.Все модели обучались на стандартны данныхБ а увеличенной и уменьшенной выборках. Для логистической регресси и случайного леса применила кроссвалидацию для улучшения качества.<br>
# Все алгоритмы показали  результат выше, чем у константного, а это свидетельствует об их адекватности.<br>
# Помимо требуемой метрики для сравнения расчитала `Accuracy` и `F1` , а также построила ROC-кривую.
# Лучший результат по всем показателям и CatBoost с увеличением выборки.<br>
# Важность признаков у каждой модели существенно отличестся.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. На основе персональных данных о некоторых клиентах, информацию об их тарифах и договорах, предоставленных заказчикам, были разработаны алгоритмы машинного обучения, прогнозирующие отток клиентов.
# 2. Исходные данные не содержали прпусков и дубликатов, однако после их объединения (необходимость использования сведения из всех таблиц) появились  пропущенные значения, поскольку некоторые клиенты не пользуются конкретными услугами. Для избегания искажения в данных, пропуски заполнять какими-либо значениями не стала. Просто показала, модели, что есть пропуски.
# 3. Для Нормальной работы алгоритма создала целевой признак,добавила несколько новых, и удалила незначимые (основываюсь, на графике значимости).
# 4. Модели классификации обчила на подготовленных данных, а также на увеличенной и уменьшенной выборках (для избежания дисбаланса).
# 5. Лучшие результаты показала модель `CatBoost`с балансом классов и на увеличенной выборке. Пожтому для прогнозирования оотока клиентов и выполнения задания заказика рекомендую использовать именно эту модель. Её качество оценено разными метриками с хорошими показателями.

# %% [markdown]
# ## Отчёт

# %% [markdown]
# Предствленная работы быа выполнена для реализации следующей задачи: обучить модель прогнозировать отток клиентов Оператор связи «Ниединогоразрыва.ком», чтобы можно было создавать персональные предложени для клиентов, желающих прекратить сотрудничество.<br>
# В первую очередь был составлен предварительнвй план работы, для того, чтобы понимать возможные моментры реализации поставленной задачи и пруктурировать саму работу.<br>
# 1. Общие пункты плата были выполнены, однако по ходу работы план корректировался взависимотсти от обнаруженных данных и поведения модели:
# - Пункт "Оценка и анализ данных" подпункт "Визуализировать данные, проверить зависимости признаков и (при необходимости) объединить таблицы" частично перенесён в следующий пункт, поскольку решила, что целесообразнее бутет проверять зависимость признаков после добавления целевого признака.
# - Пункт "Подготовка данных для построения  моделей" выполнен полностью.
# - Пункт "Моделирование" выполнен в полном объёме.
# - Обоснование и выводы в работе присутствуют.
# 2. Задача была интересная, не очень сожная, но трудности всё-таки возникли:
# - Выделение важных признаков, добавление новых и удаление менее значимых проводилось методом эксперемента с постоянным обучением модели и попыткой понять наличие утечки данных.
# - Подобрать параметы для модели таким образом, чтобы она не переобучилась. а метрика качества была требуемого уровня.
# 3. Самые важные шаги, по моему мнению: подготовка, добавление и удаление признаков, поскольку каждый из них может существенно влиять на модель. Для лучшего понимания важности признаков применяла `phik`, так как практически все данные категориальные.
# 4. Все модели, которые были обучены, показали относительно хорощие результаты. Но в результате проведённой работы была выделена модель CatBoost, которая на увеличенной выборке (для нивелирования дисбаланса данных) показала качество AUC-ROC 0.993788 и 0.918285 на трениоровочной и тестовой данных соотвественно (график ниже).
# Исходя из приведённого выще для решения текущей задачи, а именно - прогнозирования оттока клиентов Оператора связи «Ниединогоразрыва.ком» рекомендую использовать именно CatBoost на увеличенной выборке, учитывая подготовленный для её обучения набор признаков (важность вмех признаков для модели представленна на графике ниже).

# %%
importances_cat_up = pd.Series(cat_up.feature_importances_,
                         features_upsampled.columns)

fig, ax = plt.subplots(figsize=(16,10))
importances_cat_up.plot.bar(ax=ax)
ax.set_title("Признаки")
ax.set_ylabel('Степень значимости')
fig.tight_layout()

# %%
fig, axs = plt.subplots(1,2)

compare_models.plot(kind='bar', x='index', y= 'AUC-ROC_train',color='green', label='AUC_ROC обучающая выборка',ax=axs[0], figsize=(15,7))
compare_models.plot(kind='bar', x='index', y= 'AUC-ROC_test',color='blue', label='AUC_ROC тестовя выборка', ax=axs[1])


fig.suptitle('Сравнение качества  работы моделей',fontsize=20)
# Out:
# Text(0.5, 0.98, 'Сравнение качества  работы моделей')
